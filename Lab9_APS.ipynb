# %% [markdown]
# <a href="https://colab.research.google.com/github/priti191/APS-Lab/blob/main/Lab9_APS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
graph = {}
V = int(input("Enter no. of nodes: "))
for i in range(V):
  node = input("Enter node:")[0] # Changed 'mode' to 'node' for clarity
  ad = int(input(f"Enter no. of adjacents of node {node} : "))
  print("Enter adjacent and edge weight (e.g., B 4) :") # Added example for clarity
  for j in range(ad):
    neighbor, weight = input().split()
    weight = int(weight)
    if graph.get(node) :
      graph[node][neighbor] = weight
    else :
      graph[node] = {}
      graph[node][neighbor] = weight

# %%
result = dijkstra(graph, 'A')
total_path  = 0
for node in result:
    total_path += result[node]
    print("Distance from A to", node, "=", result[node])

print(f"Path with total distance : {total_path}")
# Out:
# Distance from A to A = 0
# Path with total distance : 0

# %%
V = int(input("Enter no. of nodes: "))
for i in range(V):
  node = input("Enter node:")[0]
  ad = int(input(f"Enter no. of adjacents of node {node} :"))
  print("Enter adjacent and edge weight :")
  for j in range(ad):
    neighbor, weight = input().split()
    weight = int(weight)
    if graph.get(node) :
      graph[node][neighbor] = weight
    else :
      graph[node] = {}
      graph[node][neighbor] = weight

"""
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3, 'E': 3, 'F': 5},
'D': {'B': 10, 'C': 3, 'F': 4}
'E': {'C': 3, 'B': 2, 'F': 4},
'F': {'C': 5, 'D': 4, 'E': 4}
}
"""

# %%
result = dijkstra(graph, 'A')
for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0

# %%
result = dijkstra(graph, 'B')
for node in result:
    print("Distance from B to", node, "=", result[node])
# Out:
# Distance from B to B = 0

# %%
result = dijkstra(graph, 'E')
for node in result:
    print("Distance from E to", node, "=", result[node])
# Out:
# Distance from E to E = 0
